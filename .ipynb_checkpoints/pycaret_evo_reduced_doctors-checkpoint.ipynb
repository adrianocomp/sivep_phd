# %%
import pandas as pd
import numpy as np
df = pd.read_csv("bases_de_dados/Sivep/bases_novas/not_encoded/sivep_kids_atualizado_not_encoded_reduced_evo.csv")

# %%
df.drop(df[df['outcome_final_SIVEP'] == "in-hospital"].index, inplace = True)
df['Doses_vacina'] = df['Doses_vacina'].map({'zero': 'zero', 'uma':'uma', 'duas':'duas', 'tres':'tres','missing':'zero'})
df['Doses_vacina'].value_counts()
# Out:
# zero    20184
# duas     1122
# uma       779
# tres      168
# Name: Doses_vacina, dtype: int64

# %%
df['outcome_final_SIVEP'].value_counts()
# Out:
# discharge    20742
# death         1511
# Name: outcome_final_SIVEP, dtype: int64

# %%
df.head()
# Out:
#   gender  idade_anos  etnia     region Virus_strain dyspnea fever cough  \
# 0   male   17.000000  Brown  Northeast        gamma     sim   nao   nao
# 1   male   16.416667  White      South        delta     nao   sim   sim
# 2   male   15.333333  Brown  Southeast        gamma     nao   sim   sim
# 3   male   14.333333  White  Southeast        gamma     sim   sim   nao
# 4   male   13.583333  White      North      omicron     sim   nao   nao
#
#   odynophagia abdominal_Pain ageusia anosmia REspDistress  \
# 0         nao            nao     nao     nao          sim
# 1         nao            nao     nao     nao          sim
# 2         nao            nao     nao     nao          nao
# 3         nao            nao     nao     nao          sim
# 4         nao            nao     sim     nao          sim
#
#   Oxygen_saturation_reduced  comorbidades_total outcome_final_SIVEP  \
# 0                       sim                 0.0               death
# 1                       sim                 3.0               death
# 2                       nao                 0.0               death
# 3                       nao                 0.0               death
# 4                       sim                 0.0               death
#
#   Doses_vacina nosocomial
# 0         zero        nao
# 1         zero        nao
# 2         zero        nao
# 3         zero        nao
# 4         zero        nao

# %%
from pycaret.classification import *
s = setup(df, target = 'outcome_final_SIVEP', session_id = 123, 
          log_experiment = True, experiment_name = 'evo_1', remove_multicollinearity = True, max_encoding_ohe=100, fix_imbalance=True, fix_imbalance_method="SMOTEENN")
# Out:
# <style type="text/css">
# #T_3db6b_row11_col1, #T_3db6b_row17_col1, #T_3db6b_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3db6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3db6b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3db6b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3db6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3db6b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3db6b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3db6b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3db6b_row1_col1" class="data row1 col1" >outcome_final_SIVEP</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3db6b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3db6b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3db6b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_3db6b_row3_col1" class="data row3 col1" >death: 0, discharge: 1</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3db6b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3db6b_row4_col1" class="data row4 col1" >(22253, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3db6b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3db6b_row5_col1" class="data row5 col1" >(30547, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3db6b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3db6b_row6_col1" class="data row6 col1" >(23871, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3db6b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3db6b_row7_col1" class="data row7 col1" >(6676, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3db6b_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_3db6b_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3db6b_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_3db6b_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3db6b_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_3db6b_row10_col1" class="data row10 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3db6b_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_3db6b_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3db6b_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_3db6b_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3db6b_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_3db6b_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3db6b_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_3db6b_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3db6b_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_3db6b_row15_col1" class="data row15 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3db6b_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_3db6b_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3db6b_row17_col0" class="data row17 col0" >Remove multicollinearity</td>
#       <td id="T_3db6b_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3db6b_row18_col0" class="data row18 col0" >Multicollinearity threshold</td>
#       <td id="T_3db6b_row18_col1" class="data row18 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3db6b_row19_col0" class="data row19 col0" >Fix imbalance</td>
#       <td id="T_3db6b_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3db6b_row20_col0" class="data row20 col0" >Fix imbalance method</td>
#       <td id="T_3db6b_row20_col1" class="data row20 col1" >SMOTEENN</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3db6b_row21_col0" class="data row21 col0" >Fold Generator</td>
#       <td id="T_3db6b_row21_col1" class="data row21 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3db6b_row22_col0" class="data row22 col0" >Fold Number</td>
#       <td id="T_3db6b_row22_col1" class="data row22 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3db6b_row23_col0" class="data row23 col0" >CPU Jobs</td>
#       <td id="T_3db6b_row23_col1" class="data row23 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3db6b_row24_col0" class="data row24 col0" >Use GPU</td>
#       <td id="T_3db6b_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3db6b_row25_col0" class="data row25 col0" >Log Experiment</td>
#       <td id="T_3db6b_row25_col1" class="data row25 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3db6b_row26_col0" class="data row26 col0" >Experiment Name</td>
#       <td id="T_3db6b_row26_col1" class="data row26 col1" >evo_1</td>
#     </tr>
#     <tr>
#       <th id="T_3db6b_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3db6b_row27_col0" class="data row27 col0" >USI</td>
#       <td id="T_3db6b_row27_col1" class="data row27 col1" >e30f</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
get_config('X_transformed').tail()
# Out:
#        gender  idade_anos  etnia_White  etnia_Brown  etnia_Indigenous  \
# 7542      1.0    1.000000          0.0          1.0               0.0
# 10569     1.0    1.250000          0.0          1.0               0.0
# 22777     0.0   11.500000          1.0          0.0               0.0
# 24031     0.0    2.166667          1.0          0.0               0.0
# 5261      1.0    1.000000          1.0          0.0               0.0
#
#        etnia_Black  etnia_Asian  region_Southeast  region_South  \
# 7542           0.0          0.0               1.0           0.0
# 10569          0.0          0.0               0.0           0.0
# 22777          0.0          0.0               0.0           1.0
# 24031          0.0          0.0               0.0           1.0
# 5261           0.0          0.0               1.0           0.0
#
#        region_Central_West  ...  ageusia  anosmia  REspDistress  \
# 7542                   0.0  ...      0.0      0.0           1.0
# 10569                  0.0  ...      0.0      0.0           0.0
# 22777                  0.0  ...      0.0      0.0           0.0
# 24031                  0.0  ...      0.0      0.0           0.0
# 5261                   0.0  ...      0.0      0.0           1.0
#
#        Oxygen_saturation_reduced  comorbidades_total  Doses_vacina_zero  \
# 7542                         1.0                 1.0                1.0
# 10569                        0.0                 0.0                1.0
# 22777                        1.0                 0.0                1.0
# 24031                        0.0                 0.0                1.0
# 5261                         1.0                 0.0                1.0
#
#        Doses_vacina_uma  Doses_vacina_duas  Doses_vacina_tres  nosocomial
# 7542                0.0                0.0                0.0         0.0
# 10569               0.0                0.0                0.0         0.0
# 22777               0.0                0.0                0.0         0.0
# 24031               0.0                0.0                0.0         0.0
# 5261                0.0                0.0                0.0         0.0
#
# [5 rows x 30 columns]

# %%
best = compare_models(exclude=['lightgbm', 'ridge', 'svm', 'dummy'])
# Out:
# <style type="text/css">
# #T_ff35d th {
#   text-align: left;
# }
# #T_ff35d_row0_col0, #T_ff35d_row0_col4, #T_ff35d_row0_col6, #T_ff35d_row0_col7, #T_ff35d_row1_col0, #T_ff35d_row1_col1, #T_ff35d_row1_col2, #T_ff35d_row1_col3, #T_ff35d_row1_col4, #T_ff35d_row1_col5, #T_ff35d_row1_col6, #T_ff35d_row1_col7, #T_ff35d_row2_col0, #T_ff35d_row2_col1, #T_ff35d_row2_col2, #T_ff35d_row2_col3, #T_ff35d_row2_col4, #T_ff35d_row2_col5, #T_ff35d_row2_col6, #T_ff35d_row2_col7, #T_ff35d_row3_col0, #T_ff35d_row3_col1, #T_ff35d_row3_col2, #T_ff35d_row3_col3, #T_ff35d_row3_col4, #T_ff35d_row3_col5, #T_ff35d_row3_col6, #T_ff35d_row3_col7, #T_ff35d_row4_col0, #T_ff35d_row4_col1, #T_ff35d_row4_col2, #T_ff35d_row4_col3, #T_ff35d_row4_col4, #T_ff35d_row4_col5, #T_ff35d_row4_col6, #T_ff35d_row4_col7, #T_ff35d_row5_col0, #T_ff35d_row5_col1, #T_ff35d_row5_col2, #T_ff35d_row5_col3, #T_ff35d_row5_col4, #T_ff35d_row5_col5, #T_ff35d_row5_col6, #T_ff35d_row5_col7, #T_ff35d_row6_col0, #T_ff35d_row6_col1, #T_ff35d_row6_col2, #T_ff35d_row6_col3, #T_ff35d_row6_col4, #T_ff35d_row6_col5, #T_ff35d_row7_col0, #T_ff35d_row7_col1, #T_ff35d_row7_col2, #T_ff35d_row7_col3, #T_ff35d_row7_col4, #T_ff35d_row7_col5, #T_ff35d_row7_col6, #T_ff35d_row7_col7, #T_ff35d_row8_col0, #T_ff35d_row8_col1, #T_ff35d_row8_col2, #T_ff35d_row8_col3, #T_ff35d_row8_col4, #T_ff35d_row8_col5, #T_ff35d_row8_col6, #T_ff35d_row8_col7, #T_ff35d_row9_col0, #T_ff35d_row9_col1, #T_ff35d_row9_col2, #T_ff35d_row9_col3, #T_ff35d_row9_col4, #T_ff35d_row9_col5, #T_ff35d_row9_col6, #T_ff35d_row9_col7, #T_ff35d_row10_col0, #T_ff35d_row10_col1, #T_ff35d_row10_col2, #T_ff35d_row10_col3, #T_ff35d_row10_col5, #T_ff35d_row10_col6, #T_ff35d_row10_col7, #T_ff35d_row11_col0, #T_ff35d_row11_col1, #T_ff35d_row11_col2, #T_ff35d_row11_col3, #T_ff35d_row11_col4, #T_ff35d_row11_col5, #T_ff35d_row11_col6, #T_ff35d_row11_col7 {
#   text-align: left;
# }
# #T_ff35d_row0_col1, #T_ff35d_row0_col2, #T_ff35d_row0_col3, #T_ff35d_row0_col5, #T_ff35d_row6_col6, #T_ff35d_row6_col7, #T_ff35d_row10_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff35d_row0_col8, #T_ff35d_row1_col8, #T_ff35d_row2_col8, #T_ff35d_row3_col8, #T_ff35d_row4_col8, #T_ff35d_row5_col8, #T_ff35d_row6_col8, #T_ff35d_row7_col8, #T_ff35d_row8_col8, #T_ff35d_row9_col8, #T_ff35d_row10_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff35d_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff35d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff35d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff35d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ff35d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ff35d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ff35d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ff35d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ff35d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ff35d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ff35d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff35d_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_ff35d_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ff35d_row0_col1" class="data row0 col1" >0.9208</td>
#       <td id="T_ff35d_row0_col2" class="data row0 col2" >0.8030</td>
#       <td id="T_ff35d_row0_col3" class="data row0 col3" >0.9756</td>
#       <td id="T_ff35d_row0_col4" class="data row0 col4" >0.9415</td>
#       <td id="T_ff35d_row0_col5" class="data row0 col5" >0.9583</td>
#       <td id="T_ff35d_row0_col6" class="data row0 col6" >0.1872</td>
#       <td id="T_ff35d_row0_col7" class="data row0 col7" >0.2009</td>
#       <td id="T_ff35d_row0_col8" class="data row0 col8" >1.3800</td>
#     </tr>
#     <tr>
#       <th id="T_ff35d_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_ff35d_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_ff35d_row1_col1" class="data row1 col1" >0.9192</td>
#       <td id="T_ff35d_row1_col2" class="data row1 col2" >0.8011</td>
#       <td id="T_ff35d_row1_col3" class="data row1 col3" >0.9721</td>
#       <td id="T_ff35d_row1_col4" class="data row1 col4" >0.9429</td>
#       <td id="T_ff35d_row1_col5" class="data row1 col5" >0.9573</td>
#       <td id="T_ff35d_row1_col6" class="data row1 col6" >0.2053</td>
#       <td id="T_ff35d_row1_col7" class="data row1 col7" >0.2149</td>
#       <td id="T_ff35d_row1_col8" class="data row1 col8" >1.0450</td>
#     </tr>
#     <tr>
#       <th id="T_ff35d_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ff35d_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_ff35d_row2_col1" class="data row2 col1" >0.9173</td>
#       <td id="T_ff35d_row2_col2" class="data row2 col2" >0.7943</td>
#       <td id="T_ff35d_row2_col3" class="data row2 col3" >0.9686</td>
#       <td id="T_ff35d_row2_col4" class="data row2 col4" >0.9441</td>
#       <td id="T_ff35d_row2_col5" class="data row2 col5" >0.9562</td>
#       <td id="T_ff35d_row2_col6" class="data row2 col6" >0.2183</td>
#       <td id="T_ff35d_row2_col7" class="data row2 col7" >0.2246</td>
#       <td id="T_ff35d_row2_col8" class="data row2 col8" >1.5010</td>
#     </tr>
#     <tr>
#       <th id="T_ff35d_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_ff35d_row3_col0" class="data row3 col0" >CatBoost Classifier</td>
#       <td id="T_ff35d_row3_col1" class="data row3 col1" >0.9083</td>
#       <td id="T_ff35d_row3_col2" class="data row3 col2" >0.7970</td>
#       <td id="T_ff35d_row3_col3" class="data row3 col3" >0.9567</td>
#       <td id="T_ff35d_row3_col4" class="data row3 col4" >0.9456</td>
#       <td id="T_ff35d_row3_col5" class="data row3 col5" >0.9511</td>
#       <td id="T_ff35d_row3_col6" class="data row3 col6" >0.2182</td>
#       <td id="T_ff35d_row3_col7" class="data row3 col7" >0.2193</td>
#       <td id="T_ff35d_row3_col8" class="data row3 col8" >7.6160</td>
#     </tr>
#     <tr>
#       <th id="T_ff35d_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_ff35d_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ff35d_row4_col1" class="data row4 col1" >0.8984</td>
#       <td id="T_ff35d_row4_col2" class="data row4 col2" >0.7843</td>
#       <td id="T_ff35d_row4_col3" class="data row4 col3" >0.9429</td>
#       <td id="T_ff35d_row4_col4" class="data row4 col4" >0.9478</td>
#       <td id="T_ff35d_row4_col5" class="data row4 col5" >0.9453</td>
#       <td id="T_ff35d_row4_col6" class="data row4 col6" >0.2224</td>
#       <td id="T_ff35d_row4_col7" class="data row4 col7" >0.2230</td>
#       <td id="T_ff35d_row4_col8" class="data row4 col8" >0.9940</td>
#     </tr>
#     <tr>
#       <th id="T_ff35d_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_ff35d_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_ff35d_row5_col1" class="data row5 col1" >0.8969</td>
#       <td id="T_ff35d_row5_col2" class="data row5 col2" >0.7556</td>
#       <td id="T_ff35d_row5_col3" class="data row5 col3" >0.9428</td>
#       <td id="T_ff35d_row5_col4" class="data row5 col4" >0.9464</td>
#       <td id="T_ff35d_row5_col5" class="data row5 col5" >0.9446</td>
#       <td id="T_ff35d_row5_col6" class="data row5 col6" >0.2050</td>
#       <td id="T_ff35d_row5_col7" class="data row5 col7" >0.2052</td>
#       <td id="T_ff35d_row5_col8" class="data row5 col8" >1.1580</td>
#     </tr>
#     <tr>
#       <th id="T_ff35d_level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_ff35d_row6_col0" class="data row6 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ff35d_row6_col1" class="data row6 col1" >0.8892</td>
#       <td id="T_ff35d_row6_col2" class="data row6 col2" >0.7866

# %%
best.get_params()
# Out:
# {'constant': None, 'random_state': 123, 'strategy': 'prior'}

# %%
cat = create_model('catboost')
# Out:
# <style type="text/css">
# #T_684b0_row10_col0, #T_684b0_row10_col1, #T_684b0_row10_col2, #T_684b0_row10_col3, #T_684b0_row10_col4, #T_684b0_row10_col5, #T_684b0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_684b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_684b0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_684b0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_684b0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_684b0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_684b0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_684b0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_684b0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_684b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_684b0_row0_col0" class="data row0 col0" >0.9114</td>
#       <td id="T_684b0_row0_col1" class="data row0 col1" >0.7670</td>
#       <td id="T_684b0_row0_col2" class="data row0 col2" >0.9725</td>
#       <td id="T_684b0_row0_col3" class="data row0 col3" >0.9351</td>
#       <td id="T_684b0_row0_col4" class="data row0 col4" >0.9534</td>
#       <td id="T_684b0_row0_col5" class="data row0 col5" >0.0642</td>
#       <td id="T_684b0_row0_col6" class="data row0 col6" >0.0698</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_684b0_row1_col0" class="data row1 col0" >0.9204</td>
#       <td id="T_684b0_row1_col1" class="data row1 col1" >0.7613</td>
#       <td id="T_684b0_row1_col2" class="data row1 col2" >0.9780</td>
#       <td id="T_684b0_row1_col3" class="data row1 col3" >0.9392</td>
#       <td id="T_684b0_row1_col4" class="data row1 col4" >0.9582</td>
#       <td id="T_684b0_row1_col5" class="data row1 col5" >0.1492</td>
#       <td id="T_684b0_row1_col6" class="data row1 col6" >0.1637</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_684b0_row2_col0" class="data row2 col0" >0.9243</td>
#       <td id="T_684b0_row2_col1" class="data row2 col1" >0.8023</td>
#       <td id="T_684b0_row2_col2" class="data row2 col2" >0.9835</td>
#       <td id="T_684b0_row2_col3" class="data row2 col3" >0.9382</td>
#       <td id="T_684b0_row2_col4" class="data row2 col4" >0.9603</td>
#       <td id="T_684b0_row2_col5" class="data row2 col5" >0.1393</td>
#       <td id="T_684b0_row2_col6" class="data row2 col6" >0.1620</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_684b0_row3_col0" class="data row3 col0" >0.9217</td>
#       <td id="T_684b0_row3_col1" class="data row3 col1" >0.7537</td>
#       <td id="T_684b0_row3_col2" class="data row3 col2" >0.9821</td>
#       <td id="T_684b0_row3_col3" class="data row3 col3" >0.9369</td>
#       <td id="T_684b0_row3_col4" class="data row3 col4" >0.9590</td>
#       <td id="T_684b0_row3_col5" class="data row3 col5" >0.1101</td>
#       <td id="T_684b0_row3_col6" class="data row3 col6" >0.1281</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_684b0_row4_col0" class="data row4 col0" >0.9178</td>
#       <td id="T_684b0_row4_col1" class="data row4 col1" >0.7725</td>
#       <td id="T_684b0_row4_col2" class="data row4 col2" >0.9745</td>
#       <td id="T_684b0_row4_col3" class="data row4 col3" >0.9396</td>
#       <td id="T_684b0_row4_col4" class="data row4 col4" >0.9567</td>
#       <td id="T_684b0_row4_col5" class="data row4 col5" >0.1519</td>
#       <td id="T_684b0_row4_col6" class="data row4 col6" >0.1627</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_684b0_row5_col0" class="data row5 col0" >0.9198</td>
#       <td id="T_684b0_row5_col1" class="data row5 col1" >0.7524</td>
#       <td id="T_684b0_row5_col2" class="data row5 col2" >0.9793</td>
#       <td id="T_684b0_row5_col3" class="data row5 col3" >0.9374</td>
#       <td id="T_684b0_row5_col4" class="data row5 col4" >0.9579</td>
#       <td id="T_684b0_row5_col5" class="data row5 col5" >0.1161</td>
#       <td id="T_684b0_row5_col6" class="data row5 col6" >0.1307</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_684b0_row6_col0" class="data row6 col0" >0.9268</td>
#       <td id="T_684b0_row6_col1" class="data row6 col1" >0.7946</td>
#       <td id="T_684b0_row6_col2" class="data row6 col2" >0.9842</td>
#       <td id="T_684b0_row6_col3" class="data row6 col3" >0.9401</td>
#       <td id="T_684b0_row6_col4" class="data row6 col4" >0.9616</td>
#       <td id="T_684b0_row6_col5" class="data row6 col5" >0.1788</td>
#       <td id="T_684b0_row6_col6" class="data row6 col6" >0.2051</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_684b0_row7_col0" class="data row7 col0" >0.9120</td>
#       <td id="T_684b0_row7_col1" class="data row7 col1" >0.7651</td>
#       <td id="T_684b0_row7_col2" class="data row7 col2" >0.9690</td>
#       <td id="T_684b0_row7_col3" class="data row7 col3" >0.9386</td>
#       <td id="T_684b0_row7_col4" class="data row7 col4" >0.9536</td>
#       <td id="T_684b0_row7_col5" class="data row7 col5" >0.1171</td>
#       <td id="T_684b0_row7_col6" class="data row7 col6" >0.1229</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_684b0_row8_col0" class="data row8 col0" >0.9171</td>
#       <td id="T_684b0_row8_col1" class="data row8 col1" >0.7764</td>
#       <td id="T_684b0_row8_col2" class="data row8 col2" >0.9766</td>
#       <td id="T_684b0_row8_col3" class="data row8 col3" >0.9372</td>
#       <td id="T_684b0_row8_col4" class="data row8 col4" >0.9565</td>
#       <td id="T_684b0_row8_col5" class="data row8 col5" >0.0983</td>
#       <td id="T_684b0_row8_col6" class="data row8 col6" >0.1087</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_684b0_row9_col0" class="data row9 col0" >0.9216</td>
#       <td id="T_684b0_row9_col1" class="data row9 col1" >0.7778</td>
#       <td id="T_684b0_row9_col2" class="data row9 col2" >0.9841</td>
#       <td id="T_684b0_row9_col3" class="data row9 col3" >0.9352</td>
#       <td id="T_684b0_row9_col4" class="data row9 col4" >0.9590</td>
#       <td id="T_684b0_row9_col5" class="data row9 col5" >0.0752</td>
#       <td id="T_684b0_row9_col6" class="data row9 col6" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_684b0_row10_col0" class="data row10 col0" >0.9193</td>
#       <td id="T_684b0_row10_col1" class="data row10 col1" >0.7723</td>
#       <td id="T_684b0_row10_col2" class="data row10 col2" >0.9784</td>
#       <td id="T_684b0_row10_col3" class="data row10 col3" >0.9378</td>
#       <td id="T_684b0_row10_col4" class="data row10 col4" >0.9576</td>
#       <td id="T_684b0_row10_col5" class="data row10 col5" >0.1200</td>
#       <td id="T_684b0_row10_col6" class="data row10 col6" >0.1346</td>
#     </tr>
#     <tr>
#       <th id="T_684b0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_684b0_row11_col0" class="data row11 col0" >0.0046</td>
#       <td id="T_684b0_row11_col1" class="data row11 col1" >0.0155</td>
#       <td id="T_684b0_row11_col2" class="data row11 col2" >0.0050</td>
#       <td id="T_684b0_row11_col3" class="data row11 col3" >0.0016</td>
#       <td id="T_684b0_row11_col4

# %%
evaluate_model(cat)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
data_transf = get_config('data')

# %%
data_transf.tail()
# Out:
#        gender  idade_anos idade_cat_3 idade_cat_4  etnia     region  \
# 7542     male    1.000000          <2          <2  Brown  Southeast
# 10569    male    1.250000          <2          <2  Brown  Northeast
# 22777  female   11.500000        2-11        5-11  White      South
# 24031  female    2.166667        2-11         2-4  White      South
# 5261     male    1.000000          <2          <2  White  Southeast
#
#       Virus_strain dyspnea fever cough  ... codigoRecebeuVacina Doses_vacina  \
# 7542         gamma     sim   sim   sim  ...                 nao         zero
# 10569      omicron     sim   nao   sim  ...                 nao         zero
# 22777        gamma     sim   sim   sim  ...                 nao         zero
# 24031      omicron     nao   sim   nao  ...                 nao         zero
# 5261       omicron     sim   nao   sim  ...                 nao         zero
#
#       hematology neurology oncology Transplant sind_down syndrome nosocomial  \
# 7542         nao       sim      nao        nao       nao      nao        nao
# 10569        nao       nao      nao        nao       nao      nao        nao
# 22777        nao       nao      nao        nao       nao      nao        nao
# 24031        nao       nao      nao        nao       nao      nao        nao
# 5261         nao       nao      nao        nao       nao      nao        nao
#
#       outcome_final_SIVEP
# 7542            discharge
# 10569           discharge
# 22777           discharge
# 24031           discharge
# 5261            discharge
#
# [5 rows x 40 columns]

# %%
model_data = class_df.sample(frac=0.9, random_state=786)
data_unseen = class_df.drop(model_data.index)

model_data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(model_data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))

# %%
tuned_gbc = tune_model(gbc)
# Out:
# <style type="text/css">
# #T_18335_row10_col0, #T_18335_row10_col1, #T_18335_row10_col2, #T_18335_row10_col3, #T_18335_row10_col4, #T_18335_row10_col5, #T_18335_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_18335">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18335_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_18335_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_18335_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_18335_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_18335_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_18335_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_18335_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18335_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18335_row0_col0" class="data row0 col0" >0.8601</td>
#       <td id="T_18335_row0_col1" class="data row0 col1" >0.7268</td>
#       <td id="T_18335_row0_col2" class="data row0 col2" >0.8601</td>
#       <td id="T_18335_row0_col3" class="data row0 col3" >0.7407</td>
#       <td id="T_18335_row0_col4" class="data row0 col4" >0.7960</td>
#       <td id="T_18335_row0_col5" class="data row0 col5" >-0.0009</td>
#       <td id="T_18335_row0_col6" class="data row0 col6" >-0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18335_row1_col0" class="data row1 col0" >0.8613</td>
#       <td id="T_18335_row1_col1" class="data row1 col1" >0.7313</td>
#       <td id="T_18335_row1_col2" class="data row1 col2" >0.8613</td>
#       <td id="T_18335_row1_col3" class="data row1 col3" >0.8041</td>
#       <td id="T_18335_row1_col4" class="data row1 col4" >0.7977</td>
#       <td id="T_18335_row1_col5" class="data row1 col5" >0.0076</td>
#       <td id="T_18335_row1_col6" class="data row1 col6" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18335_row2_col0" class="data row2 col0" >0.8613</td>
#       <td id="T_18335_row2_col1" class="data row2 col1" >0.6876</td>
#       <td id="T_18335_row2_col2" class="data row2 col2" >0.8613</td>
#       <td id="T_18335_row2_col3" class="data row2 col3" >0.8041</td>
#       <td id="T_18335_row2_col4" class="data row2 col4" >0.7977</td>
#       <td id="T_18335_row2_col5" class="data row2 col5" >0.0076</td>
#       <td id="T_18335_row2_col6" class="data row2 col6" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18335_row3_col0" class="data row3 col0" >0.8607</td>
#       <td id="T_18335_row3_col1" class="data row3 col1" >0.7428</td>
#       <td id="T_18335_row3_col2" class="data row3 col2" >0.8607</td>
#       <td id="T_18335_row3_col3" class="data row3 col3" >0.7408</td>
#       <td id="T_18335_row3_col4" class="data row3 col4" >0.7963</td>
#       <td id="T_18335_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_18335_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18335_row4_col0" class="data row4 col0" >0.8607</td>
#       <td id="T_18335_row4_col1" class="data row4 col1" >0.7311</td>
#       <td id="T_18335_row4_col2" class="data row4 col2" >0.8607</td>
#       <td id="T_18335_row4_col3" class="data row4 col3" >0.7408</td>
#       <td id="T_18335_row4_col4" class="data row4 col4" >0.7963</td>
#       <td id="T_18335_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_18335_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18335_row5_col0" class="data row5 col0" >0.8607</td>
#       <td id="T_18335_row5_col1" class="data row5 col1" >0.7364</td>
#       <td id="T_18335_row5_col2" class="data row5 col2" >0.8607</td>
#       <td id="T_18335_row5_col3" class="data row5 col3" >0.7408</td>
#       <td id="T_18335_row5_col4" class="data row5 col4" >0.7963</td>
#       <td id="T_18335_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_18335_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18335_row6_col0" class="data row6 col0" >0.8601</td>
#       <td id="T_18335_row6_col1" class="data row6 col1" >0.7245</td>
#       <td id="T_18335_row6_col2" class="data row6 col2" >0.8601</td>
#       <td id="T_18335_row6_col3" class="data row6 col3" >0.7398</td>
#       <td id="T_18335_row6_col4" class="data row6 col4" >0.7954</td>
#       <td id="T_18335_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_18335_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18335_row7_col0" class="data row7 col0" >0.8606</td>
#       <td id="T_18335_row7_col1" class="data row7 col1" >0.7410</td>
#       <td id="T_18335_row7_col2" class="data row7 col2" >0.8606</td>
#       <td id="T_18335_row7_col3" class="data row7 col3" >0.7407</td>
#       <td id="T_18335_row7_col4" class="data row7 col4" >0.7961</td>
#       <td id="T_18335_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_18335_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18335_row8_col0" class="data row8 col0" >0.8612</td>
#       <td id="T_18335_row8_col1" class="data row8 col1" >0.6961</td>
#       <td id="T_18335_row8_col2" class="data row8 col2" >0.8612</td>
#       <td id="T_18335_row8_col3" class="data row8 col3" >0.7417</td>
#       <td id="T_18335_row8_col4" class="data row8 col4" >0.7970</td>
#       <td id="T_18335_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_18335_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18335_row9_col0" class="data row9 col0" >0.8612</td>
#       <td id="T_18335_row9_col1" class="data row9 col1" >0.6949</td>
#       <td id="T_18335_row9_col2" class="data row9 col2" >0.8612</td>
#       <td id="T_18335_row9_col3" class="data row9 col3" >0.7417</td>
#       <td id="T_18335_row9_col4" class="data row9 col4" >0.7970</td>
#       <td id="T_18335_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_18335_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_18335_row10_col0" class="data row10 col0" >0.8608</td>
#       <td id="T_18335_row10_col1" class="data row10 col1" >0.7212</td>
#       <td id="T_18335_row10_col2" class="data row10 col2" >0.8608</td>
#       <td id="T_18335_row10_col3" class="data row10 col3" >0.7535</td>
#       <td id="T_18335_row10_col4" class="data row10 col4" >0.7966</td>
#       <td id="T_18335_row10_col5" class="data row10 col5" >0.0014</td>
#       <td id="T_18335_row10_col6" class="data row10 col6" >0.0117</td>
#     </tr>
#     <tr>
#       <th id="T_18335_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_18335_row11_col0" class="data row11 col0" >0.0004</td>
#       <td id="T_18335_row11_col1" class="data row11 col1" >0.0195</td>
#       <td id="T_18335_row11_col2" class="data row11 col2" >0.0004</td>
#       <td id="T_18335_row11_col3" class="data row11 col3" >0.0253</td>
#       <td id="T_18335_row11_co
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(gbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
print(tuned_gbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
calibrated_gbc = calibrate_model(tuned_gbc)
# Out:
# <style type="text/css">
# #T_a0cb7_row10_col0, #T_a0cb7_row10_col1, #T_a0cb7_row10_col2, #T_a0cb7_row10_col3, #T_a0cb7_row10_col4, #T_a0cb7_row10_col5, #T_a0cb7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a0cb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0cb7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a0cb7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a0cb7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a0cb7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a0cb7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a0cb7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a0cb7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0cb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0cb7_row0_col0" class="data row0 col0" >0.8595</td>
#       <td id="T_a0cb7_row0_col1" class="data row0 col1" >0.7203</td>
#       <td id="T_a0cb7_row0_col2" class="data row0 col2" >0.8595</td>
#       <td id="T_a0cb7_row0_col3" class="data row0 col3" >0.7567</td>
#       <td id="T_a0cb7_row0_col4" class="data row0 col4" >0.7968</td>
#       <td id="T_a0cb7_row0_col5" class="data row0 col5" >0.0050</td>
#       <td id="T_a0cb7_row0_col6" class="data row0 col6" >0.0206</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0cb7_row1_col0" class="data row1 col0" >0.8607</td>
#       <td id="T_a0cb7_row1_col1" class="data row1 col1" >0.7114</td>
#       <td id="T_a0cb7_row1_col2" class="data row1 col2" >0.8607</td>
#       <td id="T_a0cb7_row1_col3" class="data row1 col3" >0.7626</td>
#       <td id="T_a0cb7_row1_col4" class="data row1 col4" >0.7976</td>
#       <td id="T_a0cb7_row1_col5" class="data row1 col5" >0.0101</td>
#       <td id="T_a0cb7_row1_col6" class="data row1 col6" >0.0477</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0cb7_row2_col0" class="data row2 col0" >0.8619</td>
#       <td id="T_a0cb7_row2_col1" class="data row2 col1" >0.6909</td>
#       <td id="T_a0cb7_row2_col2" class="data row2 col2" >0.8619</td>
#       <td id="T_a0cb7_row2_col3" class="data row2 col3" >0.8045</td>
#       <td id="T_a0cb7_row2_col4" class="data row2 col4" >0.7991</td>
#       <td id="T_a0cb7_row2_col5" class="data row2 col5" >0.0152</td>
#       <td id="T_a0cb7_row2_col6" class="data row2 col6" >0.0877</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0cb7_row3_col0" class="data row3 col0" >0.8607</td>
#       <td id="T_a0cb7_row3_col1" class="data row3 col1" >0.7342</td>
#       <td id="T_a0cb7_row3_col2" class="data row3 col2" >0.8607</td>
#       <td id="T_a0cb7_row3_col3" class="data row3 col3" >0.7408</td>
#       <td id="T_a0cb7_row3_col4" class="data row3 col4" >0.7963</td>
#       <td id="T_a0cb7_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_a0cb7_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0cb7_row4_col0" class="data row4 col0" >0.8625</td>
#       <td id="T_a0cb7_row4_col1" class="data row4 col1" >0.7223</td>
#       <td id="T_a0cb7_row4_col2" class="data row4 col2" >0.8625</td>
#       <td id="T_a0cb7_row4_col3" class="data row4 col3" >0.8050</td>
#       <td id="T_a0cb7_row4_col4" class="data row4 col4" >0.8005</td>
#       <td id="T_a0cb7_row4_col5" class="data row4 col5" >0.0227</td>
#       <td id="T_a0cb7_row4_col6" class="data row4 col6" >0.1074</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0cb7_row5_col0" class="data row5 col0" >0.8607</td>
#       <td id="T_a0cb7_row5_col1" class="data row5 col1" >0.7440</td>
#       <td id="T_a0cb7_row5_col2" class="data row5 col2" >0.8607</td>
#       <td id="T_a0cb7_row5_col3" class="data row5 col3" >0.7408</td>
#       <td id="T_a0cb7_row5_col4" class="data row5 col4" >0.7963</td>
#       <td id="T_a0cb7_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_a0cb7_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0cb7_row6_col0" class="data row6 col0" >0.8601</td>
#       <td id="T_a0cb7_row6_col1" class="data row6 col1" >0.7106</td>
#       <td id="T_a0cb7_row6_col2" class="data row6 col2" >0.8601</td>
#       <td id="T_a0cb7_row6_col3" class="data row6 col3" >0.7716</td>
#       <td id="T_a0cb7_row6_col4" class="data row6 col4" >0.7965</td>
#       <td id="T_a0cb7_row6_col5" class="data row6 col5" >0.0067</td>
#       <td id="T_a0cb7_row6_col6" class="data row6 col6" >0.0388</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a0cb7_row7_col0" class="data row7 col0" >0.8594</td>
#       <td id="T_a0cb7_row7_col1" class="data row7 col1" >0.7248</td>
#       <td id="T_a0cb7_row7_col2" class="data row7 col2" >0.8594</td>
#       <td id="T_a0cb7_row7_col3" class="data row7 col3" >0.7405</td>
#       <td id="T_a0cb7_row7_col4" class="data row7 col4" >0.7956</td>
#       <td id="T_a0cb7_row7_col5" class="data row7 col5" >-0.0017</td>
#       <td id="T_a0cb7_row7_col6" class="data row7 col6" >-0.0099</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a0cb7_row8_col0" class="data row8 col0" >0.8612</td>
#       <td id="T_a0cb7_row8_col1" class="data row8 col1" >0.7020</td>
#       <td id="T_a0cb7_row8_col2" class="data row8 col2" >0.8612</td>
#       <td id="T_a0cb7_row8_col3" class="data row8 col3" >0.7732</td>
#       <td id="T_a0cb7_row8_col4" class="data row8 col4" >0.7981</td>
#       <td id="T_a0cb7_row8_col5" class="data row8 col5" >0.0068</td>
#       <td id="T_a0cb7_row8_col6" class="data row8 col6" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a0cb7_row9_col0" class="data row9 col0" >0.8624</td>
#       <td id="T_a0cb7_row9_col1" class="data row9 col1" >0.6970</td>
#       <td id="T_a0cb7_row9_col2" class="data row9 col2" >0.8624</td>
#       <td id="T_a0cb7_row9_col3" class="data row9 col3" >0.8048</td>
#       <td id="T_a0cb7_row9_col4" class="data row9 col4" >0.7998</td>
#       <td id="T_a0cb7_row9_col5" class="data row9 col5" >0.0153</td>
#       <td id="T_a0cb7_row9_col6" class="data row9 col6" >0.0879</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a0cb7_row10_col0" class="data row10 col0" >0.8609</td>
#       <td id="T_a0cb7_row10_col1" class="data row10 col1" >0.7157</td>
#       <td id="T_a0cb7_row10_col2" class="data row10 col2" >0.8609</td>
#       <td id="T_a0cb7_row10_col3" class="data row10 col3" >0.7700</td>
#       <td id="T_a0cb7_row10_col4" class="data row10 col4" >0.7977</td>
#       <td id="T_a0cb7_row10_col5" class="data row10 col5" >0.0080</td>
#       <td id="T_a0cb7_row10_col6" class="data row10 col6" >0.0419</td>
#     </tr>
#     <tr>
#       <th id="T_a0cb7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a0cb7_row11_col0" class="data row11 col0" >0.0010</td>
#       <td id="T_a0cb7_row11_col1" class="data row11 col1" >0.0158</td>
#       <td id="T_a0cb7_row11_col2" class="data row11 col2" >0.0010</td>
#       <td id="T_a0cb7_row11_col3" class="data row11 col3" >0.0254</td>
#       <td id="T_a0cb7_row11_co

# %%
interpret_model(tuned_gbc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 interpret_model(tuned_gbc)
#
# File ~/anaconda3/envs/pycaret/lib/python3.10/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pycaret/lib/python3.10/site-packages/pycaret/classification/functional.py:1905, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1807 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1808 def interpret_model(
#    1809     estimator,
#    (...)
#    1817     **kwargs,
#    1818 ):
#    1819     """
#    1820     This function takes a trained model object and returns an interpretation plot
#    1821     based on the test / hold-out set.
#    (...)
#    1902
#    1903     """
# -> 1905     return _CURRENT_EXPERIMENT.interpret_model(
#    1906         estimator=estimator,
#    1907         plot=plot,
#    1908         feature=feature,
#    1909         observation=observation,
#    1910         use_train_data=use_train_data,
#    1911         X_new_sample=X_new_sample,
#    1912         y_new_sample=y_new_sample,
#    1913         save=save,
#    1914         **kwargs,
#    1915     )
#
# File ~/anaconda3/envs/pycaret/lib/python3.10/site-packages/pycaret/classification/oop.py:2249, in ClassificationExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2151 def interpret_model(
#    2152     self,
#    2153     estimator,
#    (...)
#    2161     **kwargs,
#    2162 ):
#    2163     """
#    2164     This function takes a trained model object and returns an interpretation plot
#    2165     based on the test / hold-out set.
#    (...)
#    2246
#    2247     """
# -> 2249     return super().interpret_model(
#    2250         estimator=estimator,
#    2251         plot=plot,
#    2252         feature=feature,
#    2253         observation=observation,
#    2254         use_train_data=use_train_data,
#    2255         X_new_sample=X_new_sample,
#    2256         y_new_sample=y_new_sample,
#    2257         save=save,
#    2258         **kwargs,
#    2259     )
#
# File ~/anaconda3/envs/pycaret/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:4068, in _SupervisedExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4063 shap_models_ids = set(shap_models.keys())
#    4065 if plot in ["summary", "correlation", "reason"] and (
#    4066     model_id not in shap_models_ids
#    4067 ):
# -> 4068     raise TypeError(
#    4069         f"This function only supports tree based models for binary classification: {', '.join(shap_models_ids)}."
#    4070     )
#    4072 # plot type
#    4073 allowed_types = ["summary", "correlation", "reason", "pdp", "msa", "pfi"]
#
# TypeError: This function only supports tree based models for binary classification: xgboost, catboost, dt, et, lightgbm, rf.
