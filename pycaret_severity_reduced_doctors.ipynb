# %%
import pandas as pd
import numpy as np
df = pd.read_csv("bases_de_dados/Sivep/bases_novas/not_encoded/severity/sivep_kids_atualizado_not_encoded_severity_reduced_doctors.csv")
#df['UTI'] = df['UTI'].map({'nao':'nao', 'sim':'sim', 'ignorado':'nao'})
df['Doses_vacina'] = df['Doses_vacina'].map({'zero': 'zero', 'uma':'uma', 'duas':'duas', 'tres':'tres','missing':'zero'})

# %%
from pycaret.classification import *
s = setup(df, target = 'outcome_geral_severe', session_id = 11, 
          log_experiment = True, experiment_name = 'sev_3', max_encoding_ohe=100)
# Out:
# <style type="text/css">
# #T_b1d0f_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b1d0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1d0f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b1d0f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1d0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1d0f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b1d0f_row0_col1" class="data row0 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b1d0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1d0f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b1d0f_row1_col1" class="data row1 col1" >outcome_geral_severe</td>
#     </tr>
#     <tr>
#       <th id="T_b1d0f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(exclude=['lightgbm', 'ridge', 'svm', 'dummy'])
# Out:
# <style type="text/css">
# #T_6cfa5 th {
#   text-align: left;
# }
# ...
