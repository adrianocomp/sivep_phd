# %%
import pandas as pd
import numpy as np
df = pd.read_csv("bases_de_dados/Sivep/bases_novas/not_encoded/severity/sivep_kids_atualizado_not_encoded_severity_full.csv")
#df['UTI'] = df['UTI'].map({'nao':'nao', 'sim':'sim', 'ignorado':'nao'})
df['Doses_vacina'] = df['Doses_vacina'].map({'zero': 'zero', 'uma':'uma', 'duas':'duas', 'tres':'tres','missing':'zero'})

# %%
df['outcome_geral_severe'].value_counts()
# Out:
# mild/moderate    17089
# severe            7008
# Name: outcome_geral_severe, dtype: int64

# %%
from pycaret.classification import *
s = setup(df, target = 'outcome_geral_severe', session_id = 9, 
          log_experiment = True, experiment_name = 'sev_1', remove_multicollinearity = True, max_encoding_ohe=100)
# Out:
# <style type="text/css">
# #T_0d690_row11_col1, #T_0d690_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0d690">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d690_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0d690_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d690_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d690_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0d690_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_0d690_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d690_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0d690_row1_col1" class="data row1 col1" >outcome_geral_severe</td>
#     </tr>
#     <tr>
# ...

# %%
best = compare_models(exclude=['lightgbm', 'ridge', 'svm', 'dummy'])
# Out:
# <style type="text/css">
# #T_2ca50 th {
#   text-align: left;
# }
# ...

# %%
get_config('y_transformed')
# Out:
# 15730    0
# 14921    0
# 18691    0
# 13012    0
# 9169     0
#         ..
# 10605    0
# 15623    0
# 10849    0
# 2440     1
# 1200     1
# Name: outcome_geral_severe, Length: 24097, dtype: int64
