# %%
import pandas as pd
import numpy as np
df = pd.read_csv("bases_de_dados/Sivep/bases_novas/not_encoded/suport_vent/sivep_kids_atualizado_not_encoded_suport_vent_reduced_doctors.csv")
df['Doses_vacina'] = df['Doses_vacina'].map({'zero': 'zero', 'uma':'uma', 'duas':'duas', 'tres':'tres','missing':'zero'})

# %%
df['suport_vent'] = df['suport_vent'].map({'nao':'nao', 'ignorado':'nao', 'nao_invasivo':'nao_invasivo', 'invasivo':'invasivo'})

# %%
from pycaret.classification import *
s = setup(df, target = 'suport_vent', session_id = 6, 
          log_experiment = True, experiment_name = 'sup_2', max_encoding_ohe=100)
# Out:
# <style type="text/css">
# #T_4d45c_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4d45c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d45c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4d45c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d45c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d45c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4d45c_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4d45c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4d45c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4d45c_row1_col1" class="data row1 col1" >suport_vent</td>
#     </tr>
#     <tr>
#       <th id="T_4d45c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(exclude=['lightgbm', 'ridge', 'svm', 'dummy'])
# Out:
# <style type="text/css">
# #T_28bd7 th {
#   text-align: left;
# }
# ...
